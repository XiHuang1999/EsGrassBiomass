# %%
import ee,os,json
import geemap
# method 1: 设置代理
os.environ['HTTP_PROXY'] = 'http://127.0.0.1:10809'
# os.environ['HTTPS_PROXY'] = 'https://127.0.0.1:10809'
# # method 2: 设置代理
# geemap.set_proxy(port=10809)
ee.Initialize()
Map = geemap.Map(center=(37, 102), zoom=4)

# %%
'''===========Set Parameters==========='''
qtp_file = r'G:\1_BeiJingUP\AUGB\Data\20220629\Shp\QTP_WGS84.shp' # boundary shp
pt_file = r'G:\1_BeiJingUP\AUGB\Temp\20102.shp' # boundary shp
qtp = ee.FeatureCollection(r'projects/ucas-agb/assets/QTP_WGS84')
# pt = geemap.shp_to_ee(pt_shp)

def clipRoi(image):
    '''
    Image裁剪
    :param image: Image,image of needed to clip
    :return: image after clip by qtp
    '''
    clip_img = image.clip(qtp)
    return clip_img
def jsonPrint(data):
    '''
    格式化输出JSON对象
    :param data: JSON object;
    :return: None
    '''
    print(json.dumps(data, sort_keys=True, indent=2)) # 排序并且缩进两个字符输出

# %%
# MCD15A3H.061: Leaf Area Index/FPAR 4-Day Global 500m ; From 2002-07-04  '''MODIS/061/MCD15A3H'''
# MOD15A2H.061: Terra Leaf Area Index/FPAR 8-Day Global 500m MODIS/061/MOD15A2H; From 2002-07-04 '''MODIS/061/MOD15A2H'''
lai = ee.ImageCollection("MODIS/061/MOD15A2H")\
                .filterDate('2010-05-01', '2010-09-30')\
                .select('Lai_500m')\
                .map(clipRoi) #.filterBounds(bd)
fpar = ee.ImageCollection("MODIS/061/MOD15A2H")\
                .filterDate('2010-05-01', '2010-09-30')\
                .map(clipRoi) #.filterBounds(bd)


colorizedVis = {'min': 0,'max': 100,
                'palette': ['FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
                          '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
                          '012E01', '011D01', '011301']}


Map.addLayer(bd, {}, 'QTP Boundary')
# Map.addLayer(pt, {}, 'ROI Point')
Map.addLayer(lai, {}, 'MOD15A2H_LAI')
Map.addLayer(fpar, {}, 'MOD15A2H_FPar')
Map
# Out:
# Map(center=[37, 102], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(To…

# %%
jsonPrint(collection.getInfo())
# Out:
# {
#   "bands": [],
#   "features": [
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_05_01",
#       "properties": {
#         "google:max_source_file_timestamp": 1627423708000,
#         "system:asset_size": 1395929123,
#         "system:index": "2010_05_01",
#         "system:time_end": 1273363200000,
#         "system:time_start": 1272672000000
#       },
#       "type": "Image",
#       "version": 1646533381568372
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_05_09",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425307000,
#         "system:asset_size": 1408410681,
#         "system:index": "2010_05_09",
#         "system:time_end": 1274054400000,
#         "system:time_start": 1273363200000
#       },
#       "type": "Image",
#       "version": 1646521155940270.0
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_05_17",
#       "properties": {
#         "google:max_source_file_timestamp": 1627608880000,
#         "system:asset_size": 1470047121,
#         "system:index": "2010_05_17",
#         "system:time_end": 1274745600000,
#         "system:time_start": 1274054400000
#       },
#       "type": "Image",
#       "version": 1645670328955798
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_05_25",
#       "properties": {
#         "google:max_source_file_timestamp": 1627606831000,
#         "system:asset_size": 1500697760,
#         "system:index": "2010_05_25",
#         "system:time_end": 1275436800000,
#         "system:time_start": 1274745600000
#       },
#       "type": "Image",
#       "version": 1645936721443079
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_06_02",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425287000,
#         "system:asset_size": 1529899574,
#         "system:index": "2010_06_02",
#         "system:time_end": 1276128000000,
#         "system:time_start": 1275436800000
#       },
#       "type": "Image",
#       "version": 1646015783917136
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_06_10",
#       "properties": {
#         "google:max_source_file_timestamp": 1627608815000,
#         "system:asset_size": 1533998550,
#         "system:index": "2010_06_10",
#         "system:time_end": 1276819200000,
#         "system:time_start": 1276128000000
#       },
#       "type": "Image",
#       "version": 1646537069659185
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_06_18",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425264000,
#         "system:asset_size": 1551921508,
#         "system:index": "2010_06_18",
#         "system:time_end": 1277510400000,
#         "system:time_start": 1276819200000
#       },
#       "type": "Image",
#       "version": 1645898555745172
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_06_26",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425244000,
#         "system:asset_size": 1550198300,
#         "system:index": "2010_06_26",
#         "system:time_end": 1278201600000,
#         "system:time_start": 1277510400000
#       },
#       "type": "Image",
#       "version": 1645924251789117
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_07_04",
#       "properties": {
#         "google:max_source_file_timestamp": 1627383080000,
#         "system:asset_size": 1576565344,
#         "system:index": "2010_07_04",
#         "system:time_end": 1278892800000,
#         "system:time_start": 1278201600000
#       },
#       "type": "Image",
#       "version": 1645504257288126
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_07_12",
#       "properties": {
#         "google:max_source_file_timestamp": 1627383054000,
#         "system:asset_size": 1589791760,
#         "system:index": "2010_07_12",
#         "system:time_end": 1279584000000,
#         "system:time_start": 1278892800000
#       },
#       "type": "Image",
#       "version": 1645847234414629
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_07_20",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425021000,
#         "system:asset_size": 1583418806,
#         "system:index": "2010_07_20",
#         "system:time_end": 1280275200000,
#         "system:time_start": 1279584000000
#       },
#       "type": "Image",
#       "version": 1645948769214003
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_07_28",
#       "properties": {
#         "google:max_source_file_timestamp": 1627383009000,
#         "system:asset_size": 1580038640,
#         "system:index": "2010_07_28",
#         "system:time_end": 1280966400000,
#         "system:time_start": 1280275200000
#       },
#       "type": "Image",
#       "version": 1645887669676851
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_08_05",
#       "properties": {
#         "google:max_source_file_timestamp": 1627425239000,
#         "system:asset_size": 1569236444,
#         "system:index": "2010_08_05",
#         "system:time_end": 1281657600000,
#         "system:time_start": 1280966400000
#       },
#       "type": "Image",
#       "version": 1646017736164391
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_08_13",
#       "properties": {
#         "google:max_source_file_timestamp": 1627382981000,
#         "system:asset_size": 1571218130,
#         "system:index": "2010_08_13",
#         "system:time_end": 1282348800000,
#         "system:time_start": 1281657600000
#       },
#       "type": "Image",
#       "version": 1645481625305286
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
# ...
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_08_21",
#       "properties": {
#         "google:max_source_file_timestamp": 1627382960000,
#         "system:asset_size": 1541669339,
#         "system:index": "2010_08_21",
#         "system:time_end": 1283040000000,
#         "system:time_start": 1282348800000
#       },
#       "type": "Image",
#       "version": 1645961035017917
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_08_29",
#       "properties": {
#         "google:max_source_file_timestamp": 1627382948000,
#         "system:asset_size": 1536536691,
#         "system:index": "2010_08_29",
#         "system:time_end": 1283731200000,
#         "system:time_start": 1283040000000
#       },
#       "type": "Image",
#       "version": 1646520513614116
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_09_06",
#       "properties": {
#         "google:max_source_file_timestamp": 1627380789000,
#         "system:asset_size": 1516599262,
#         "system:index": "2010_09_06",
#         "system:time_end": 1284422400000,
#         "system:time_start": 1283731200000
#       },
#       "type": "Image",
#       "version": 1646460516788887
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_09_14",
#       "properties": {
#         "google:max_source_file_timestamp": 1627608787000,
#         "system:asset_size": 1500762170,
#         "system:index": "2010_09_14",
#         "system:time_end": 1285113600000,
#         "system:time_start": 1284422400000
#       },
#       "type": "Image",
#       "version": 1645704021534872
#     },
#     {
#       "bands": [
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Fpar_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "Lai_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparLai_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparExtra_QC"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "FparStdDev_500m"
#         },
#         {
#           "crs": "SR-ORG:6974",
#           "crs_transform": [
#             463.3127165279165,
#             0,
#             -20015109.354,
#             0,
#             -463.3127165279167,
#             10007554.677003
#           ],
#           "data_type": {
#             "max": 255,
#             "min": 0,
#             "precision": "int",
#             "type": "PixelType"
#           },
#           "dimensions": [
#             86400,
#             36000
#           ],
#           "id": "LaiStdDev_500m"
#         }
#       ],
#       "id": "MODIS/061/MOD15A2H/2010_09_22",
#       "properties": {
#         "google:max_source_file_timestamp": 1628637035000,
#         "system:asset_size": 1439810010,
#         "system:index": "2010_09_22",
#         "system:time_end": 1285804800000,
#         "system:time_start": 1285113600000
#       },
#       "type": "Image",
#       "version": 1645929030814742
#     }
#   ],
#   "id": "MODIS/061/MOD15A2H",
#   "properties": {
#     "system:is_global": 1
#   },
#   "type": "ImageCollection",
#   "version": 1656674851155213
# }

# %%
kk = ['1','2','3','1','2','3']
kk.sort()
print(kk)
# Out:
# ['1', '1', '2', '2', '3', '3']
